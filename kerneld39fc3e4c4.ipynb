# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
2+3

# %%
6/3

# %%
x=1:10
x
mean(x)
median(x)
var(x)
sd(x)

# %%
# cat and print ,both can be used for printing
cat(x)
cat('Mean of x is:',mean(x))
cat('Median of x is :',median(x))
cat('Variance of x is:',var(x))
cat('Standard Deviation of x is:',sd(x))

# %%
#To print in next line use \n
cat(x,'\n')
cat('Mean of x is:',mean(x),'\n')
cat('Median of x is :',median(x),'\n')
cat('Variance of x is:',var(x),'\n')
cat('Standard Deviation of x is:',sd(x),'\n')

# %%
print(x)
print(paste('Mean of x is:',mean(x)))
print(paste('Median of x is :',median(x)))
print(paste('Variance of x is:',var(x)))
print(paste('Standard Deviation of x is:',sd(x)))

# %%
x=8+7
x

# %%
#Creation of character value
x="dataset"
x
class(x)
typeof(x)
length(x)
attributes(x)

# %%
#Creation of numerical variable
x=23
x
class(x)
typeof(x)
length(x)
attributes(x)

# %%
#Craetion of integer VAriable
x=23L
x
class(x)
typeof(x)
length(x)
attributes(x)

# %%
#Creation of complex variable
x=2+3i
x
class(x)
typeof(x)
length(x)
attributes(x)

# %%
#Creation of logical variable
x=TRUE
x
class(x)
typeof(x)
length(x)
attributes(x)

# %%
#An Empty logical vector
vector()

# %%
#A vector of mode character with 5 elements
vector("character",length=5)

# %%
#Same but usinbg the constructor directly
character(5)

# %%
#A numeric vector with 5 elements
numeric(5)

# %%
#A logical vector with 5 elements
logical(5)

# %%
#Numeric vector having 5 elements
x=c(12,23,34,45,56)

# %%
x
class(x)

# %%
#Integer having 5 elements
x=c(12L,23L,34L,45L,56L)
x
class(x)
length(x)

# %%
#Logical vector having 5 vectors
y=c(TRUE,TRUE,FALSE,TRUE,FALSE)
y
class(y)
length(y)

# %%
#character vector having3 elements
z=c("HELLO","TO","TIRED")
z
class(z)
length(z)

# %%
#Adding element at the end
print("Elements in Z before")
z
z=c(z,"SORRY")
print("Elemenyts in z after adding new elements")
z

# %%
#Add element at the front
print("Elements in Z before")
z
z=c("HEY",z)
print("Elemenyts in z after adding new elements")
z

# %%
#Vector from a sequence of numbers
a=1:10
a

# %%
seq(10)

# %%
seq(1,10,by=0.1)

# %%
#Special values
1/0

# %%
0/0

# %%
#e raised to the power of infinity is infinity
exp(Inf)
#e raised to the power of negative infinity is zero
exp(-Inf)

# %%
Inf-Inf

# %%
log(0)
log(1)

# %%
#Mixing types in a vector
a=c(1.7,"a")
a

# %%
b=c(TRUE,2,3,FALSE)#TRUE value is converted to 1 and FALSE to 0
b

# %%
c=c("a",TRUE)
c

# %%
#EXPLICIT TYPE CONVERSION
as.numeric("1")#conversion from character to numeric

# %%
as.numeric(c("49","66"))

# %%
as.numeric(c("49","66","six"))#Invalid conversion ,Missing values will be introduced

# %%
as.character(22)#Conversion from numeric to chracter
as.character(c(22,23,24))#Conversion from numeric to character

# %%
#MATRIX
m=matrix(nrow=2,ncol=2)
m

# %%
dim(m)
class(m)
typeof(m)

# %%
m=matrix(c(1:3))
print("Given matrix is")
print(m)
print("Dimensions of given matrix")
print(dim(m))
print("Class of given matrix is:")
print(class(m))
print("Type of given matrix is:")
print(typeof(m))

# %%
a=matrix(1:6,nrow=2,ncol=3)
print(a)

# %%
m=1:10
print(m)
print(dim(m))
dim(m)=c(2,5)
print(m)
print(dim(m))

# %%
name=readline(prompt="Enter name:")
age=readline(prompt="Enter age:")
age=as.integer(age)
print(paste("HI,",name,"next year you will be",age+1,"years old"))

# %%
w=readline()
w
